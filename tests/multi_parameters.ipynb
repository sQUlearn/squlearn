# %%
import numpy as np
from squlearn.encoding_circuit import ChebyshevRx
from squlearn.observables import SummedPaulis
from squlearn import Executor

from squlearn.qnn.lowlevel_qnn_pennylane import LowLevelQNNPennyLane
from squlearn.qnn.lowlevel_qnn_qiskit import LowLevelQNN

# %%
pqc = ChebyshevRx(2,1)
obs = SummedPaulis(2)

np.random.seed(0)
param = np.random.rand(pqc.num_parameters)
param_obs = np.random.rand(obs.num_parameters)

qnn_pl = LowLevelQNNPennyLane(pqc, obs, None)
# Out:
# self._pennylane_gates [<class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.non_parametric_ops.CNOT'>]
# self._pennylane_gates_param_function [(<function _lambdifygenerated at 0x000002919BB5C310>,), (<function _lambdifygenerated at 0x000002919BA97E20>,), (<function _lambdifygenerated at 0x000002919BB5C820>,), (<function _lambdifygenerated at 0x000002919BB5D510>,), None]
# self._pennylane_gates_wires [[0], [1], [0], [1], [0, 1]]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_gates_parameters ['param', 'x']

# %%
qnn_qiskit = LowLevelQNN(pqc, obs, Executor())

# %%
val = qnn_qiskit.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"f")["f"]
print(val)
print(val.shape)
# Out:
# [[[0.71705433 1.43410866]
#   [0.23032806 0.46065613]]
#
#  [[0.77869643 1.55739287]
#   [0.23026255 0.4605251 ]]]
# (2, 2, 2)

# %%
val = qnn_pl.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"f")["f"]
print(val)
print(val.shape)
# Out:
# param_ [0.5488135  0.71518937 0.60276338 0.54488318]
# x_ [0.5]
# param_obs_ [0.4236548  0.64589411 0.43758721]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.5, requires_grad=False)]
# value 0.7170543287605057
# param_ [0.5488135  0.71518937 0.60276338 0.54488318]
# x_ [0.5]
# param_obs_ [0.8473096  1.29178823 0.87517442]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.5, requires_grad=False)]
# value 1.4341086575210114
# param_ [1.09762701 1.43037873 1.20552675 1.08976637]
# x_ [0.5]
# param_obs_ [0.4236548  0.64589411 0.43758721]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.5, requires_grad=False)]
# value 0.2303280627118604
# param_ [1.09762701 1.43037873 1.20552675 1.08976637]
# x_ [0.5]
# param_obs_ [0.8473096  1.29178823 0.87517442]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.5, requires_grad=False)]
# value 0.4606561254237208
# param_ [0.5488135  0.71518937 0.60276338 0.54488318]
# x_ [0.6]
# param_obs_ [0.4236548  0.64589411 0.43758721]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.6, requires_grad=False)]
# value 0.7786964342526816
# param_ [0.5488135  0.71518937 0.60276338 0.54488318]
# x_ [0.6]
# param_obs_ [0.8473096  1.29178823 0.87517442]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.6, requires_grad=False)]
# value 1.5573928685053633
# param_ [1.09762701 1.43037873 1.20552675 1.08976637]
# x_ [0.6]
# param_obs_ [0.4236548  0.64589411 0.43758721]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.6, requires_grad=False)]
# value 0.23026254802201032
# param_ [1.09762701 1.43037873 1.20552675 1.08976637]
# x_ [0.6]
# param_obs_ [0.8473096  1.29178823 0.87517442]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.6, requires_grad=False)]
# value 0.46052509604402064
# values [0.71705433 1.43410866 0.23032806 0.46065613 0.77869643 1.55739287
#  0.23026255 0.4605251 ]
# values.shape (8,)
# shape before reshape (8,)
# reshape_list [2, 2, 2]
# [[[0.71705433 1.43410866]
#   [0.23032806 0.46065613]]
#
#  [[0.77869643 1.55739287]
#   [0.23026255 0.4605251 ]]]
# (2, 2, 2)

# %%
val = qnn_qiskit.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdp")["dfdp"]
print(val)
print(val.shape)
# Out:
# [[[[-0.74046648 -0.16892925 -0.70709341 -0.16131555]
#    [-1.48093297 -0.33785849 -1.41418681 -0.3226311 ]]
#
#   [[-0.20295213  0.1702392  -0.19380501  0.16256646]
#    [-0.40590426  0.3404784  -0.38761002  0.32513292]]]
#
#
#  [[[-0.6659767  -0.16812202 -0.71819275 -0.18130366]
#    [-1.33195341 -0.33624403 -1.4363855  -0.36260732]]
#
#   [[-0.23465263  0.16347324 -0.25305062  0.1762904 ]
#    [-0.46930526  0.32694649 -0.50610124  0.3525808 ]]]]
# (2, 2, 2, 4)

# %%
val = qnn_pl.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdp")["dfdp"]
print(val)
print(val.shape)
# Out:
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCF2C40>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFD600>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFF3C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFD140>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BA87700>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BA874C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919A0AA880>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x0000029197149C80>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFD940>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFC5C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BC22B40>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BC22C80>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919B9744C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BACB900>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x0000029199DE4F40>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BD41FC0>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCDC640>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919B922300>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BA43FC0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919A0BC800>, tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFE3C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFD900>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFFA80>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFFB00>, tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BC21800>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BC21DC0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCFC040>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCF1000>, tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919A094D00>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BB84D40>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCDD0C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCDCA00>, tensor(0.6, requires_grad=False)]
# values [[-0.74046648 -0.16892925 -0.70709341 -0.16131555]
#  [-1.48093297 -0.33785849 -1.41418681 -0.3226311 ]
#  [-0.20295213  0.1702392  -0.19380501  0.16256646]
#  [-0.40590426  0.3404784  -0.38761002  0.32513292]
#  [-0.6659767  -0.16812202 -0.71819275 -0.18130366]
#  [-1.33195341 -0.33624403 -1.4363855  -0.36260732]
#  [-0.23465263  0.16347324 -0.25305062  0.1762904 ]
#  [-0.46930526  0.32694649 -0.50610124  0.3525808 ]]
# values.shape (8, 4)
# shape before reshape (8, 4)
# reshape_list [2, 2, 2, 4]
# [[[[-0.74046648 -0.16892925 -0.70709341 -0.16131555]
#    [-1.48093297 -0.33785849 -1.41418681 -0.3226311 ]]
#
#   [[-0.20295213  0.1702392  -0.19380501  0.16256646]
#    [-0.40590426  0.3404784  -0.38761002  0.32513292]]]
#
#
#  [[[-0.6659767  -0.16812202 -0.71819275 -0.18130366]
#    [-1.33195341 -0.33624403 -1.4363855  -0.36260732]]
#
#   [[-0.23465263  0.16347324 -0.25305062  0.1762904 ]
#    [-0.46930526  0.32694649 -0.50610124  0.3525808 ]]]]
# (2, 2, 2, 4)

# %%
val = qnn_qiskit.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdop")["dfdop"]
print(val)
print(val.shape)
# Out:
# [[[[ 1.          0.38325405  0.10479738]
#    [ 1.          0.38325405  0.10479738]]
#
#   [[ 1.         -0.70623267  0.60062264]
#    [ 1.         -0.70623267  0.60062264]]]
#
#
#  [[[ 1.          0.44316014  0.15724205]
#    [ 1.          0.44316014  0.15724205]]
#
#   [[ 1.         -0.60721818  0.45432406]
#    [ 1.         -0.60721818  0.45432406]]]]
# (2, 2, 2, 3)

# %%
val = qnn_pl.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdop")["dfdop"]
print(val)
print(val.shape)
# Out:
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), tensor(0.6, requires_grad=False)]
# values [[ 1.          0.38325405  0.10479738]
#  [ 1.          0.38325405  0.10479738]
#  [ 1.         -0.70623267  0.60062264]
#  [ 1.         -0.70623267  0.60062264]
#  [ 1.          0.44316014  0.15724205]
#  [ 1.          0.44316014  0.15724205]
#  [ 1.         -0.60721818  0.45432406]
#  [ 1.         -0.60721818  0.45432406]]
# values.shape (8, 3)
# shape before reshape (8, 3)
# reshape_list [2, 2, 2, 3]
# [[[[ 1.          0.38325405  0.10479738]
#    [ 1.          0.38325405  0.10479738]]
#
#   [[ 1.         -0.70623267  0.60062264]
#    [ 1.         -0.70623267  0.60062264]]]
#
#
#  [[[ 1.          0.44316014  0.15724205]
#    [ 1.          0.44316014  0.15724205]]
#
#   [[ 1.         -0.60721818  0.45432406]
#    [ 1.         -0.60721818  0.45432406]]]]
# (2, 2, 2, 3)

# %%
val = qnn_qiskit.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdx")["dfdx"]
print(val)
print(val.shape)
# Out:
# [[[[ 0.58131502]
#    [ 1.16263004]]
#
#   [[-0.02287   ]
#    [-0.04573999]]]
#
#
#  [[[ 0.65477541]
#    [ 1.30955082]]
#
#   [[ 0.03199145]
#    [ 0.0639829 ]]]]
# (2, 2, 2, 1)

# %%
val = qnn_pl.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdx")["dfdx"]
print(val)
print(val.shape)
# Out:
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002913B1F9900>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BB92080>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCDDE80>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BB578C0>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BD36840>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(0.5488135, requires_grad=False), tensor(0.71518937, requires_grad=False), tensor(0.60276338, requires_grad=False), tensor(0.54488318, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCDEB40>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BABDBC0>]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [tensor(1.09762701, requires_grad=False), tensor(1.43037873, requires_grad=False), tensor(1.20552675, requires_grad=False), tensor(1.08976637, requires_grad=False), <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BBBA040>]
# values [[ 0.58131502]
#  [ 1.16263004]
#  [-0.02287   ]
#  [-0.04573999]
#  [ 0.65477541]
#  [ 1.30955082]
#  [ 0.03199145]
#  [ 0.0639829 ]]
# values.shape (8, 1)
# shape before reshape (8, 1)
# reshape_list [2, 2, 2, 1]
# [[[[ 0.58131502]
#    [ 1.16263004]]
#
#   [[-0.02287   ]
#    [-0.04573999]]]
#
#
#  [[[ 0.65477541]
#    [ 1.30955082]]
#
#   [[ 0.03199145]
#    [ 0.0639829 ]]]]
# (2, 2, 2, 1)

# %%
val = qnn_qiskit.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdpdp")["dfdpdp"]
print(val)
print(val.shape)
# Out:
# [[[[[-0.32174859  0.42633485 -0.30724727  0.4071198 ]
#     [ 0.42633485 -0.05028892  0.4071198  -0.04802238]
#     [-0.30724727  0.4071198  -0.29339953  0.38877077]
#     [ 0.4071198  -0.04802238  0.38877077 -0.04585799]]
#
#    [[-0.64349717  0.85266971 -0.61449454  0.81423959]
#     [ 0.85266971 -0.10057784  0.81423959 -0.09604476]
#     [-0.61449454  0.81423959 -0.58679906  0.77754154]
#     [ 0.81423959 -0.09604476  0.77754154 -0.09171599]]]
#
#
#   [[[ 0.21200649  0.17871511  0.20245129  0.17066036]
#     [ 0.17871511 -0.28821963  0.17066036 -0.27522947]
#     [ 0.20245129  0.17066036  0.19332674  0.16296864]
#     [ 0.17066036 -0.27522947  0.16296864 -0.26282478]]
#
#    [[ 0.42401298  0.35743021  0.40490257  0.34132071]
#     [ 0.35743021 -0.57643926  0.34132071 -0.55045894]
#     [ 0.40490257  0.34132071  0.38665347  0.32593727]
#     [ 0.34132071 -0.55045894  0.32593727 -0.52564957]]]]
#
#
#
#  [[[[-0.30529193  0.31535835 -0.32922841  0.34008409]
#     [ 0.31535835 -0.05916561  0.34008409 -0.0638045 ]
#     [-0.32922841  0.34008409 -0.35504163  0.36674846]
#     [ 0.34008409 -0.0638045   0.36674846 -0.06880711]]
#
#    [[-0.61058386  0.63071671 -0.65845682  0.68016819]
#     [ 0.63071671 -0.11833122  0.68016819 -0.12760901]
#     [-0.65845682  0.68016819 -0.71008327  0.73349692]
#     [ 0.68016819 -0.12760901  0.73349692 -0.13761422]]]
#
#
#   [[[ 0.16629344  0.19835038  0.17933171  0.21390208]
#     [ 0.19835038 -0.17094894  0.21390208 -0.18435222]
#     [ 0.17933171  0.21390208  0.19339225  0.23067312]
#     [ 0.21390208 -0.18435222  0.23067312 -0.1988064 ]]
#
#    [[ 0.33258687  0.39670076  0.35866342  0.42780417]
#     [ 0.39670076 -0.34189787  0.42780417 -0.36870445]
#     [ 0.35866342  0.42780417  0.3867845   0.46134624]
#     [ 0.42780417 -0.36870445  0.46134624 -0.3976128 ]]]]]
# (2, 2, 2, 4, 4)

# %%
val = qnn_pl.evaluate([0.5,0.6],[param,param*2],[param_obs,param_obs*2],"dfdpdp")["dfdpdp"]
print(val)
print(val.shape)
# Out:
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF96700>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF969C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF96C80>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF96F80>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFB7B40>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFB41C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFB5AC0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFB7E40>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BBAA640>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BEE1E80>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BEE38C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BEE0B80>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BEDBE00>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFA2340>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFA1EC0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BBAB3C0>, tensor(0.5, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF14980>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF17440>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF16480>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF15180>, tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF96000>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF3D9C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF3E700>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF97E00>, tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF3FAC0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFA0FC0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFA13C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BFA0F00>, tensor(0.6, requires_grad=False)]
# self._pennylane_gates_parameters ['param', 'x']
# self._pennylane_obs_parameters ['param_obs']
# circ_param_list [<autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BCE8F00>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF273C0>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BF27D40>, <autograd.numpy.numpy_boxes.ArrayBox object at 0x000002919BE74280>, tensor(0.6, requires_grad=False)]
# values [[[-0.32174859  0.42633485 -0.30724727  0.4071198 ]
#   [ 0.42633485 -0.05028892  0.4071198  -0.04802238]
#   [-0.30724727  0.4071198  -0.29339953  0.38877077]
#   [ 0.4071198  -0.04802238  0.38877077 -0.04585799]]
#
#  [[-0.64349717  0.85266971 -0.61449454  0.81423959]
#   [ 0.85266971 -0.10057784  0.81423959 -0.09604476]
#   [-0.61449454  0.81423959 -0.58679906  0.77754154]
#   [ 0.81423959 -0.09604476  0.77754154 -0.09171599]]
#
#  [[ 0.21200649  0.17871511  0.20245129  0.17066036]
#   [ 0.17871511 -0.28821963  0.17066036 -0.27522947]
#   [ 0.20245129  0.17066036  0.19332674  0.16296864]
#   [ 0.17066036 -0.27522947  0.16296864 -0.26282478]]
#
#  [[ 0.42401298  0.35743021  0.40490257  0.34132071]
#   [ 0.35743021 -0.57643926  0.34132071 -0.55045894]
#   [ 0.40490257  0.34132071  0.38665347  0.32593727]
#   [ 0.34132071 -0.55045894  0.32593727 -0.52564957]]
#
#  [[-0.30529193  0.31535835 -0.32922841  0.34008409]
#   [ 0.31535835 -0.05916561  0.34008409 -0.0638045 ]
#   [-0.32922841  0.34008409 -0.35504163  0.36674846]
#   [ 0.34008409 -0.0638045   0.36674846 -0.06880711]]
#
#  [[-0.61058386  0.63071671 -0.65845682  0.68016819]
#   [ 0.63071671 -0.11833122  0.68016819 -0.12760901]
#   [-0.65845682  0.68016819 -0.71008327  0.73349692]
#   [ 0.68016819 -0.12760901  0.73349692 -0.13761422]]
#
#  [[ 0.16629344  0.19835038  0.17933171  0.21390208]
#   [ 0.19835038 -0.17094894  0.21390208 -0.18435222]
#   [ 0.17933171  0.21390208  0.19339225  0.23067312]
#   [ 0.21390208 -0.18435222  0.23067312 -0.1988064 ]]
#
#  [[ 0.33258687  0.39670076  0.35866342  0.42780417]
#   [ 0.39670076 -0.34189787  0.42780417 -0.36870445]
#   [ 0.35866342  0.42780417  0.3867845   0.46134624]
#   [ 0.42780417 -0.36870445  0.46134624 -0.3976128 ]]]
# values.shape (8, 4, 4)
# shape before reshape (8, 4, 4)
# reshape_list [2, 2, 2, 4, 4]
# [[[[[-0.32174859  0.42633485 -0.30724727  0.4071198 ]
#     [ 0.42633485 -0.05028892  0.4071198  -0.04802238]
#     [-0.30724727  0.4071198  -0.29339953  0.38877077]
#     [ 0.4071198  -0.04802238  0.38877077 -0.04585799]]
#
#    [[-0.64349717  0.85266971 -0.61449454  0.81423959]
#     [ 0.85266971 -0.10057784  0.81423959 -0.09604476]
#     [-0.61449454  0.81423959 -0.58679906  0.77754154]
#     [ 0.81423959 -0.09604476  0.77754154 -0.09171599]]]
#
#
#   [[[ 0.21200649  0.17871511  0.20245129  0.17066036]
#     [ 0.17871511 -0.28821963  0.17066036 -0.27522947]
#     [ 0.20245129  0.17066036  0.19332674  0.16296864]
#     [ 0.17066036 -0.27522947  0.16296864 -0.26282478]]
#
#    [[ 0.42401298  0.35743021  0.40490257  0.34132071]
#     [ 0.35743021 -0.57643926  0.34132071 -0.55045894]
#     [ 0.40490257  0.34132071  0.38665347  0.32593727]
#     [ 0.34132071 -0.55045894  0.32593727 -0.52564957]]]]
#
#
#
#  [[[[-0.30529193  0.31535835 -0.32922841  0.34008409]
#     [ 0.31535835 -0.05916561  0.34008409 -0.0638045 ]
#     [-0.32922841  0.34008409 -0.35504163  0.36674846]
#     [ 0.34008409 -0.0638045   0.36674846 -0.06880711]]
#
#    [[-0.61058386  0.63071671 -0.65845682  0.68016819]
#     [ 0.63071671 -0.11833122  0.68016819 -0.12760901]
#     [-0.65845682  0.68016819 -0.71008327  0.73349692]
#     [ 0.68016819 -0.12760901  0.73349692 -0.13761422]]]
#
#
#   [[[ 0.16629344  0.19835038  0.17933171  0.21390208]
#     [ 0.19835038 -0.17094894  0.21390208 -0.18435222]
#     [ 0.17933171  0.21390208  0.19339225  0.23067312]
#     [ 0.21390208 -0.18435222  0.23067312 -0.1988064 ]]
#
#    [[ 0.33258687  0.39670076  0.35866342  0.42780417]
#     [ 0.39670076 -0.34189787  0.42780417 -0.36870445]
#     [ 0.35866342  0.42780417  0.3867845   0.46134624]
#     [ 0.42780417 -0.36870445  0.46134624 -0.3976128 ]]]]]
# (2, 2, 2, 4, 4)
