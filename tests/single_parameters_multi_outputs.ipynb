# %%
import numpy as np
from squlearn.encoding_circuit import ChebyshevRx
from squlearn.observables import SummedPaulis
from squlearn import Executor

from squlearn.qnn.lowlevel_qnn_pennylane import LowLevelQNNPennyLane
from squlearn.qnn.lowlevel_qnn_qiskit import LowLevelQNN

# %%
pqc = ChebyshevRx(2,2)
obs1 = SummedPaulis(2)
obs2 = SummedPaulis(2)

np.random.seed(0)
param = np.random.rand(pqc.num_parameters)
param_obs = np.random.rand(obs1.num_parameters+obs2.num_parameters)

qnn_pl = LowLevelQNNPennyLane(pqc, [obs1,obs2], None)
# Out:
# self._pennylane_gates [<class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.parametric_ops_single_qubit.RX'>, <class 'pennylane.ops.qubit.non_parametric_ops.CNOT'>]
# self._pennylane_gates_param_function [(<function _lambdifygenerated at 0x000002BF1842F910>,), (<function _lambdifygenerated at 0x000002BEB5F0C550>,), (<function _lambdifygenerated at 0x000002BF1842EEF0>,), (<function _lambdifygenerated at 0x000002BF184D4CA0>,), None]
# self._pennylane_gates_wires [[0], [1], [0], [1], [0, 1]]
# self._pennylane_gates_parameters ['param', 'x']
# ...

# %%
qnn_qiskit = LowLevelQNN(pqc, [obs1,obs2], Executor())

# %%
val = qnn_qiskit.evaluate([0.5,0.6],param,param_obs,"f")["f"]
print(val)
print(val.shape)
# Out:
# [0.73070215 1.3132434 ]
# (2,)

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,param_obs*2],"f")["f"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([[0.5, 0.7],
#         [0.6, 0.8]], requires_grad=False), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[0.73070215 0.86989083]
#  [1.3132434  1.48435549]]
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([[0.5, 0.7],
#         [0.6, 0.8]], requires_grad=False), tensor([0.8473096 , 1.29178823, 0.87517442, 1.783546  , 1.92732552,
#         0.76688304], requires_grad=False))
# value [[1.46140429 1.73978166]
#  [2.62648681 2.96871098]]
# eval_tuple (tensor([1.09762701, 1.43037873, 1.20552675, 1.08976637], requires_grad=False), tensor([[0.5, 0.7],
#         [0.6, 0.8]], requires_grad=False), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
# ...

# %%
val = qnn_qiskit.evaluate([0.5,0.6],param,param_obs,"dfdp")["dfdp"]
print(val)
print(val.shape)
# Out:
# [[-0.77491014 -0.1453954  -0.73998467 -0.15679515]
#  [-1.0636851  -0.12740462 -1.01574445 -0.1373938 ]]
# (2, 4)

# %%
val = qnn_pl.evaluate([0.5,0.6],param,param_obs,"dfdp")["dfdp"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([[0.5],
#         [0.6]], requires_grad=False), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# arg_index 0
# value [[[-0.77491014 -0.1453954  -0.73998467 -0.15679515]]
#
#  [[-1.0636851  -0.12740462 -1.01574445 -0.1373938 ]]]
# [[-0.77491014 -0.1453954  -0.73998467 -0.15679515]
#  [-1.0636851  -0.12740462 -1.01574445 -0.1373938 ]]
# (2, 4)

# %%
val = qnn_qiskit.evaluate([0.5,0.6],param,param_obs,"dfdop")["dfdop"]
print(val)
print(val.shape)
# Out:
# [[1.         0.38325405 0.13598618 0.         0.         0.        ]
#  [0.         0.         0.         1.         0.38325405 0.13598618]]
# (2, 6)

# %%
val = qnn_pl.evaluate([0.5,0.6],param,param_obs,"dfdop")["dfdop"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([[0.5],
#         [0.6]], requires_grad=False), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=True))
# arg_index 2
# value [[[1.         0.38325405 0.13598618 0.         0.         0.        ]]
#
#  [[0.         0.         0.         1.         0.38325405 0.13598618]]]
# [[1.         0.38325405 0.13598618 0.         0.         0.        ]
#  [0.         0.         0.         1.         0.38325405 0.13598618]]
# (2, 6)

# %%
val = qnn_qiskit.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,2*param_obs],"dfdpdx")["dfdpdx"]
print(val)
print(val.shape)
# Out:
# [[[[[[ 1.05822501 -0.35376078]
#      [-0.22205583  0.24532364]
#      [ 0.19458059 -0.33781666]
#      [-0.23946617  0.05319741]]
#
#     [[ 1.45257898 -0.30998752]
#      [-0.19457933  0.21496805]
#      [ 0.26709222 -0.29601627]
#      [-0.20983536  0.04661492]]]
#
#
#    [[[ 2.11645003 -0.70752157]
#      [-0.44411167  0.49064728]
#      [ 0.38916117 -0.67563333]
#      [-0.47893234  0.10639481]]
#
#     [[ 2.90515796 -0.61997503]
#      [-0.38915866  0.4299361 ]
#      [ 0.53418444 -0.59203254]
#      [-0.41967073  0.09322984]]]]
#
#
#
#   [[[[-0.03816857 -0.38485261]
#      [-0.24157219  0.12706908]
#      [-0.28507967 -0.36750718]
#      [-0.26051271  0.41342282]]
#
#     [[-0.08110591 -0.33723214]
#      [-0.21168079  0.11134595]
#      [-0.60577708 -0.32203297]
#      [-0.22827767  0.36226716]]]
#
#
#    [[[-0.07633714 -0.76970523]
#      [-0.48314438  0.25413816]
#      [-0.57015935 -0.73501435]
#      [-0.52102542  0.82684565]]
#
#     [[-0.16221182 -0.67446428]
# ...

# %%
val = qnn_qiskit.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,2*param_obs],"dfdx")["dfdx"]
print(val)
print(val.shape)
# Out:
# [[[[[ 0.46893957  0.14017278]
#     [ 0.64369274  0.12282823]]
#
#    [[ 0.93787914  0.28034557]
#     [ 1.28738549  0.24565647]]]
#
#
#   [[[ 0.28578493 -0.36660024]
#     [ 0.60727571 -0.32123826]]
#
#    [[ 0.57156987 -0.73320048]
#     [ 1.21455142 -0.64247652]]]]
#
#
#
#  [[[[ 0.58326869  0.22317997]
#     [ 0.77455604  0.19556437]]
#
#    [[ 1.16653739  0.44635994]
#     [ 1.54911209  0.39112874]]]
#
#
#   [[[ 0.61745411 -0.4590531 ]
#     [ 1.07517188 -0.40225128]]
#
#    [[ 1.23490823 -0.91810619]
#     [ 2.15034375 -0.80450256]]]]]
# (2, 2, 2, 2, 2)

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,2*param_obs],"dfdx")["dfdx"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([[0.5, 0.7],
#         [0.6, 0.8]], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# arg_index 1
# value [[[[0.46893957 0.        ]
#    [0.14017278 0.        ]]
#
#   [[0.         0.58326869]
#    [0.         0.22317997]]]
#
#
#  [[[0.64369274 0.        ]
#    [0.12282823 0.        ]]
#
#   [[0.         0.77455604]
#    [0.         0.19556437]]]]
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([[0.5, 0.7],
#         [0.6, 0.8]], requires_grad=True), tensor([0.8473096 , 1.29178823, 0.87517442, 1.783546  , 1.92732552,
#         0.76688304], requires_grad=False))
# arg_index 1
# value [[[[0.93787914 0.        ]
#    [0.28034557 0.        ]]
#
#   [[0.         1.16653739]
# ...

# %%
val = qnn_qiskit.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,2*param_obs],"dfdpdx")["dfdpdx"]
print(val)
print(val.shape)
# Out:
# [[[[[[ 1.05822501 -0.35376078]
#      [-0.22205583  0.24532364]
#      [ 0.19458059 -0.33781666]
#      [-0.23946617  0.05319741]]
#
#     [[ 1.45257898 -0.30998752]
#      [-0.19457933  0.21496805]
#      [ 0.26709222 -0.29601627]
#      [-0.20983536  0.04661492]]]
#
#
#    [[[ 2.11645003 -0.70752157]
#      [-0.44411167  0.49064728]
#      [ 0.38916117 -0.67563333]
#      [-0.47893234  0.10639481]]
#
#     [[ 2.90515796 -0.61997503]
#      [-0.38915866  0.4299361 ]
#      [ 0.53418444 -0.59203254]
#      [-0.41967073  0.09322984]]]]
#
#
#
#   [[[[-0.03816857 -0.38485261]
#      [-0.24157219  0.12706908]
#      [-0.28507967 -0.36750718]
#      [-0.26051271  0.41342282]]
#
#     [[-0.08110591 -0.33723214]
#      [-0.21168079  0.11134595]
#      [-0.60577708 -0.32203297]
#      [-0.22827767  0.36226716]]]
#
#
#    [[[-0.07633714 -0.76970523]
#      [-0.48314438  0.25413816]
#      [-0.57015935 -0.73501435]
#      [-0.52102542  0.82684565]]
#
#     [[-0.16221182 -0.67446428]
# ...

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,2*param_obs],"dfdpdx")["dfdpdx"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([0.5, 0.6], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[ 1.05822501 -0.22205583  0.19458059 -0.23946617]
#   [-0.35376078  0.24532364 -0.33781666  0.05319741]]
#
#  [[ 1.45257898 -0.19457933  0.26709222 -0.20983536]
#   [-0.30998752  0.21496805 -0.29601627  0.04661492]]]
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([0.5, 0.6], requires_grad=True), tensor([0.8473096 , 1.29178823, 0.87517442, 1.783546  , 1.92732552,
#         0.76688304], requires_grad=False))
# value [[[ 2.11645003 -0.44411167  0.38916117 -0.47893234]
#   [-0.70752157  0.49064728 -0.67563333  0.10639481]]
#
#  [[ 2.90515796 -0.38915866  0.53418444 -0.41967073]
# ...

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],param,param_obs,"dfdxdp")["dfdxdp"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([0.5, 0.6], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[ 1.05822501 -0.35376078]
#   [-0.22205583  0.24532364]
#   [ 0.19458059 -0.33781666]
#   [-0.23946617  0.05319741]]
#
#  [[ 1.45257898 -0.30998752]
#   [-0.19457933  0.21496805]
#   [ 0.26709222 -0.29601627]
#   [-0.20983536  0.04661492]]]
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([0.7, 0.8], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[ 1.33554663 -0.30192877]
#   [-0.15748484  0.40323958]
#   [ 0.3429291  -0.37959419]
#   [-0.24473126  0.14169735]]
#
#  [[ 1.77354919 -0.26456904]
# ...

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],[param,2*param],[param_obs,2*param_obs],"dfdxdxdp")["dfdxdxdp"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([0.5, 0.6], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[[ 0.56731878  0.48309926]
#    [ 0.48309926 -0.2116269 ]]
#
#   [[-0.08964716  0.37467174]
#    [ 0.37467174  0.21319918]]
#
#   [[ 0.42689455  0.08882963]
#    [ 0.08882963 -0.2020888 ]]
#
#   [[-0.09667596  0.081246  ]
#    [ 0.081246    0.17518517]]]
#
#
#  [[[ 0.77873356  0.42332204]
#    [ 0.42332204 -0.18544084]]
#
#   [[-0.07855449  0.32831101]
#    [ 0.32831101  0.18681857]]
#
#   [[ 0.58597939  0.07783813]
#    [ 0.07783813 -0.17708296]]
#
#   [[-0.08471358  0.07119287]
#    [ 0.07119287  0.1535083 ]]]]
# ...

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],param,param_obs,"dfdxdpdx")["dfdxdpdx"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([0.5, 0.6], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[[ 0.56731878  0.48309926]
#    [-0.08964716  0.37467174]
#    [ 0.42689455  0.08882963]
#    [-0.09667596  0.081246  ]]
#
#   [[ 0.48309926 -0.2116269 ]
#    [ 0.37467174  0.21319918]
#    [ 0.08882963 -0.2020888 ]
#    [ 0.081246    0.17518517]]]
#
#
#  [[[ 0.77873356  0.42332204]
#    [-0.07855449  0.32831101]
#    [ 0.58597939  0.07783813]
#    [-0.08471358  0.07119287]]
#
#   [[ 0.42332204 -0.18544084]
#    [ 0.32831101  0.18681857]
#    [ 0.07783813 -0.17708296]
#    [ 0.07119287  0.1535083 ]]]]
# ...

# %%
val = qnn_pl.evaluate([[0.5,0.6],[0.7,0.8]],param,param_obs,"dfdxdx")["dfdxdx"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([0.5, 0.6], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[0.1893177  0.21407957]
#   [0.21407957 0.08385421]]
#
#  [[0.25986808 0.18759003]
#   [0.18759003 0.07347835]]]
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=False), tensor([0.7, 0.8], requires_grad=True), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# value [[[0.53702639 0.29171533]
#   [0.29171533 0.32705476]]
#
#  [[0.71314824 0.25561937]
#   [0.25561937 0.28658602]]]
# [[[[0.1893177  0.21407957]
#    [0.21407957 0.08385421]]
#
#   [[0.25986808 0.18759003]
#    [0.18759003 0.07347835]]]
#
#
#  [[[0.53702639 0.29171533]
#    [0.29171533 0.32705476]]
#
# ...

# %%
val = qnn_qiskit.evaluate([0.5,0.6],param,param_obs,"dfdpdp")["dfdpdp"]
print(val)
print(val.shape)
# Out:
# [[[-0.33671509  0.36694134 -0.32153923  0.39571146]
#   [ 0.36694134 -0.05116764  0.35040317 -0.05517946]
#   [-0.32153923  0.35040317 -0.30704735  0.37787661]
#   [ 0.39571146 -0.05517946  0.37787661 -0.05950581]]
#
#  [[-0.46219402  0.32153715 -0.44136277  0.34674734]
#   [ 0.32153715 -0.04483632  0.30704536 -0.04835172]
#   [-0.44136277  0.30704536 -0.4214704   0.33111932]
#   [ 0.34674734 -0.04835172  0.33111932 -0.05214275]]]
# (2, 4, 4)

# %%
val = qnn_pl.evaluate([0.5,0.6],param,param_obs,"dfdpdp")["dfdpdp"]
print(val)
print(val.shape)
# Out:
# self._pennylane_circuit.circuit_arguments ['param', 'x', 'param_obs']
# eval_tuple (tensor([0.5488135 , 0.71518937, 0.60276338, 0.54488318], requires_grad=True), tensor([[0.5],
#         [0.6]], requires_grad=False), tensor([0.4236548 , 0.64589411, 0.43758721, 0.891773  , 0.96366276,
#         0.38344152], requires_grad=False))
# arg_index 0
# arg_index 0
# value [[[[-0.33671509  0.36694134 -0.32153923  0.39571146]
#    [ 0.36694134 -0.05116764  0.35040317 -0.05517946]
#    [-0.32153923  0.35040317 -0.30704735  0.37787661]
#    [ 0.39571146 -0.05517946  0.37787661 -0.05950581]]]
#
#
#  [[[-0.46219402  0.32153715 -0.44136277  0.34674734]
#    [ 0.32153715 -0.04483632  0.30704536 -0.04835172]
#    [-0.44136277  0.30704536 -0.4214704   0.33111932]
#    [ 0.34674734 -0.04835172  0.33111932 -0.05214275]]]]
# [[[-0.33671509  0.36694134 -0.32153923  0.39571146]
#   [ 0.36694134 -0.05116764  0.35040317 -0.05517946]
#   [-0.32153923  0.35040317 -0.30704735  0.37787661]
# ...
