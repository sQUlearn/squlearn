# %%
from squlearn import Executor
from squlearn.encoding_circuit import ChebyshevPQC

from qiskit_ibm_runtime import QiskitRuntimeService,Sampler,Session

from qiskit import QuantumCircuit

service = QiskitRuntimeService(channel="ibm_quantum")

# %%
l = service.backends()
exec = Executor(l,max_session_time=200)
print(exec.backend_list)
# Out:
# self._remote True
# self._estimator None
# type(self._estimator) <class 'NoneType'>
# [<IBMBackend('ibm_torino')>, <IBMBackend('ibmq_kolkata')>, <IBMBackend('ibmq_mumbai')>, <IBMBackend('ibm_brisbane')>, <IBMBackend('ibm_nazca')>, <IBMBackend('ibm_cusco')>, <IBMBackend('ibm_kyoto')>, <IBMBackend('ibm_cairo')>, <IBMBackend('ibm_hanoi')>, <IBMBackend('ibm_sherbrooke')>, <IBMBackend('ibm_algiers')>, <IBMBackend('ibm_osaka')>, <IBMBackend('ibmq_qasm_simulator')>, <IBMBackend('simulator_extended_stabilizer')>, <IBMBackend('simulator_mps')>, <IBMBackend('simulator_statevector')>, <IBMBackend('simulator_stabilizer')>]

# %%
pqc = ChebyshevPQC(10,1,2)
pqc2,info = exec.select_backend(encoding_circuit=pqc)
pqc2.draw()
# Out:
# Number of backends available with given parameters:12
# Mode: quality using Mapomatic
# Input circuit needs 10 qubits
# Transpiling circuit 1 times for 1 compatible backends...
# Two-qubit gate count: [61]
# Best Two-qubit gate count (ID:0): 61
# Transpiled circuit needs 13 qubits
# Searching best sub-layout on 12 backends...
# Best sub-layout: [27, 28, 29, 30, 31, 32, 35, 36, 47, 48, 49, 50, 51] on backend: ibm_osaka. Error_rate: 0.36822082648687793
# C:\Users\DKR\AppData\Roaming\Python\Python310\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
exec.backend
# Out:
# <IBMBackend('ibm_osaka')>

# %%
print(info)
# Out:
# (Layout({
# 27: Qubit(QuantumRegister(13, 'q'), 0),
# 28: Qubit(QuantumRegister(13, 'q'), 1),
# 29: Qubit(QuantumRegister(13, 'q'), 2),
# 30: Qubit(QuantumRegister(13, 'q'), 3),
# 31: Qubit(QuantumRegister(13, 'q'), 4),
# 32: Qubit(QuantumRegister(13, 'q'), 5),
# 35: Qubit(QuantumRegister(13, 'q'), 6),
# 36: Qubit(QuantumRegister(13, 'q'), 7),
# 47: Qubit(QuantumRegister(13, 'q'), 8),
# 48: Qubit(QuantumRegister(13, 'q'), 9),
# 49: Qubit(QuantumRegister(13, 'q'), 10),
# 50: Qubit(QuantumRegister(13, 'q'), 11),
# 51: Qubit(QuantumRegister(13, 'q'), 12),
# 0: Qubit(QuantumRegister(114, 'ancilla'), 0),
# 1: Qubit(QuantumRegister(114, 'ancilla'), 1),
# 2: Qubit(QuantumRegister(114, 'ancilla'), 2),
# 3: Qubit(QuantumRegister(114, 'ancilla'), 3),
# 4: Qubit(QuantumRegister(114, 'ancilla'), 4),
# 5: Qubit(QuantumRegister(114, 'ancilla'), 5),
# 6: Qubit(QuantumRegister(114, 'ancilla'), 6),
# 7: Qubit(QuantumRegister(114, 'ancilla'), 7),
# 8: Qubit(QuantumRegister(114, 'ancilla'), 8),
# 9: Qubit(QuantumRegister(114, 'ancilla'), 9),
# 10: Qubit(QuantumRegister(114, 'ancilla'), 10),
# 11: Qubit(QuantumRegister(114, 'ancilla'), 11),
# 12: Qubit(QuantumRegister(114, 'ancilla'), 12),
# 13: Qubit(QuantumRegister(114, 'ancilla'), 13),
# 14: Qubit(QuantumRegister(114, 'ancilla'), 14),
# 15: Qubit(QuantumRegister(114, 'ancilla'), 15),
# 16: Qubit(QuantumRegister(114, 'ancilla'), 16),
# 17: Qubit(QuantumRegister(114, 'ancilla'), 17),
# 18: Qubit(QuantumRegister(114, 'ancilla'), 18),
# 19: Qubit(QuantumRegister(114, 'ancilla'), 19),
# 20: Qubit(QuantumRegister(114, 'ancilla'), 20),
# 21: Qubit(QuantumRegister(114, 'ancilla'), 21),
# 22: Qubit(QuantumRegister(114, 'ancilla'), 22),
# 23: Qubit(QuantumRegister(114, 'ancilla'), 23),
# 24: Qubit(QuantumRegister(114, 'ancilla'), 24),
# 25: Qubit(QuantumRegister(114, 'ancilla'), 25),
# 26: Qubit(QuantumRegister(114, 'ancilla'), 26),
# 33: Qubit(QuantumRegister(114, 'ancilla'), 27),
# 34: Qubit(QuantumRegister(114, 'ancilla'), 28),
# 37: Qubit(QuantumRegister(114, 'ancilla'), 29),
# 38: Qubit(QuantumRegister(114, 'ancilla'), 30),
# 39: Qubit(QuantumRegister(114, 'ancilla'), 31),
# 40: Qubit(QuantumRegister(114, 'ancilla'), 32),
# 41: Qubit(QuantumRegister(114, 'ancilla'), 33),
# 42: Qubit(QuantumRegister(114, 'ancilla'), 34),
# 43: Qubit(QuantumRegister(114, 'ancilla'), 35),
# 44: Qubit(QuantumRegister(114, 'ancilla'), 36),
# 45: Qubit(QuantumRegister(114, 'ancilla'), 37),
# 46: Qubit(QuantumRegister(114, 'ancilla'), 38),
# 52: Qubit(QuantumRegister(114, 'ancilla'), 39),
# 53: Qubit(QuantumRegister(114, 'ancilla'), 40),
# 54: Qubit(QuantumRegister(114, 'ancilla'), 41),
# 55: Qubit(QuantumRegister(114, 'ancilla'), 42),
# 56: Qubit(QuantumRegister(114, 'ancilla'), 43),
# 57: Qubit(QuantumRegister(114, 'ancilla'), 44),
# 58: Qubit(QuantumRegister(114, 'ancilla'), 45),
# 59: Qubit(QuantumRegister(114, 'ancilla'), 46),
# 60: Qubit(QuantumRegister(114, 'ancilla'), 47),
# 61: Qubit(QuantumRegister(114, 'ancilla'), 48),
# 62: Qubit(QuantumRegister(114, 'ancilla'), 49),
# 63: Qubit(QuantumRegister(114, 'ancilla'), 50),
# 64: Qubit(QuantumRegister(114, 'ancilla'), 51),
# 65: Qubit(QuantumRegister(114, 'ancilla'), 52),
# 66: Qubit(QuantumRegister(114, 'ancilla'), 53),
# 67: Qubit(QuantumRegister(114, 'ancilla'), 54),
# 68: Qubit(QuantumRegister(114, 'ancilla'), 55),
# 69: Qubit(QuantumRegister(114, 'ancilla'), 56),
# 70: Qubit(QuantumRegister(114, 'ancilla'), 57),
# 71: Qubit(QuantumRegister(114, 'ancilla'), 58),
# 72: Qubit(QuantumRegister(114, 'ancilla'), 59),
# 73: Qubit(QuantumRegister(114, 'ancilla'), 60),
# 74: Qubit(QuantumRegister(114, 'ancilla'), 61),
# 75: Qubit(QuantumRegister(114, 'ancilla'), 62),
# 76: Qubit(QuantumRegister(114, 'ancilla'), 63),
# 77: Qubit(QuantumRegister(114, 'ancilla'), 64),
# 78: Qubit(QuantumRegister(114, 'ancilla'), 65),
# 79: Qubit(QuantumRegister(114, 'ancilla'), 66),
# 80: Qubit(QuantumRegister(114, 'ancilla'), 67),
# 81: Qubit(QuantumRegister(114, 'ancilla'), 68),
# 82: Qubit(QuantumRegister(114, 'ancilla'), 69),
# 83: Qubit(QuantumRegister(114, 'ancilla'), 70),
# 84: Qubit(QuantumRegister(114, 'ancilla'), 71),
# 85: Qubit(QuantumRegister(114, 'ancilla'), 72),
# 86: Qubit(QuantumRegister(114, 'ancilla'), 73),
# 87: Qubit(QuantumRegister(114, 'ancilla'), 74),
# 88: Qubit(QuantumRegister(114, 'ancilla'), 75),
# 89: Qubit(QuantumRegister(114, 'ancilla'), 76),
# 90: Qubit(QuantumRegister(114, 'ancilla'), 77),
# 91: Qubit(QuantumRegister(114, 'ancilla'), 78),
# 92: Qubit(QuantumRegister(114, 'ancilla'), 79),
# 93: Qubit(QuantumRegister(114, 'ancilla'), 80),
# 94: Qubit(QuantumRegister(114, 'ancilla'), 81),
# 95: Qubit(QuantumRegister(114, 'ancilla'), 82),
# 96: Qubit(QuantumRegister(114, 'ancilla'), 83),
# 97: Qubit(QuantumRegister(114, 'ancilla'), 84),
# 98: Qubit(QuantumRegister(114, 'ancilla'), 85),
# 99: Qubit(QuantumRegister(114, 'ancilla'), 86),
# 100: Qubit(QuantumRegister(114, 'ancilla'), 87),
# 101: Qubit(QuantumRegister(114, 'ancilla'), 88),
# 102: Qubit(QuantumRegister(114, 'ancilla'), 89),
# 103: Qubit(QuantumRegister(114, 'ancilla'), 90),
# 104: Qubit(QuantumRegister(114, 'ancilla'), 91),
# 105: Qubit(QuantumRegister(114, 'ancilla'), 92),
# 106: Qubit(QuantumRegister(114, 'ancilla'), 93),
# 107: Qubit(QuantumRegister(114, 'ancilla'), 94),
# 108: Qubit(QuantumRegister(114, 'ancilla'), 95),
# 109: Qubit(QuantumRegister(114, 'ancilla'), 96),
# 110: Qubit(QuantumRegister(114, 'ancilla'), 97),
# 111: Qubit(QuantumRegister(114, 'ancilla'), 98),
# 112: Qubit(QuantumRegister(114, 'ancilla'), 99),
# 113: Qubit(QuantumRegister(114, 'ancilla'), 100),
# 114: Qubit(QuantumRegister(114, 'ancilla'), 101),
# 115: Qubit(QuantumRegister(114, 'ancilla'), 102),
# 116: Qubit(QuantumRegister(114, 'ancilla'), 103),
# 117: Qubit(QuantumRegister(114, 'ancilla'), 104),
# 118: Qubit(QuantumRegister(114, 'ancilla'), 105),
# 119: Qubit(QuantumRegister(114, 'ancilla'), 106),
# 120: Qubit(QuantumRegister(114, 'ancilla'), 107),
# 121: Qubit(QuantumRegister(114, 'ancilla'), 108),
# 122: Qubit(QuantumRegister(114, 'ancilla'), 109),
# 123: Qubit(QuantumRegister(114, 'ancilla'), 110),
# 124: Qubit(QuantumRegister(114, 'ancilla'), 111),
# 125: Qubit(QuantumRegister(114, 'ancilla'), 112),
# 126: Qubit(QuantumRegister(114, 'ancilla'), 113)
# }), 0.36822082648687793)
