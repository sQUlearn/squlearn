# %%
import numpy as np
from squlearn.feature_map import ChebPQC
from squlearn.expectation_operator import SummedPaulis, IsingHamiltonian

from squlearn.qnn.qnn_optree import QNN

from squlearn.qnn.qnn import QNN as QNN_old

from squlearn import Executor

fm = ChebPQC(3, 1, 1)
op = SummedPaulis(3)
op2 = SummedPaulis(3)


qnn = QNN(fm, [op, op2], Executor(), result_caching=False)
x = 0.5
np.random.seed(0)
params = np.random.rand(qnn.num_parameters)
params_op = np.random.rand(qnn.num_parameters_operator)

# %%
qnn_old = QNN_old(fm, [op, op2], Executor(), result_caching=False)
res1 = qnn_old.evaluate(
    ("dvardp",), [x, x], [params, 2 * params, 3 * params], [params_op, params_op]
)

# %%
res2 = qnn.evaluate(("dvardp",), [x, x], [params, 2 * params, 3 * params], [params_op, params_op])
# Out:
# pre-processing 0.049036502838134766
# Total number of circuits: 180
# sampler run time 0.2944157123565674
# post processing 0.12303662300109863
# val.shape (6, 2, 12, 2, 2)
# swapp_list inital [0, 1, 2, 3, 4]
# num_nested 1
# swapp_list [3, 0, 1, 4, 2]
# after val.shape (2, 6, 2, 2, 12)
# reshape_list [2, 3, 2, 2, 12]
# reshape_list [2, 3, 2, 2, 12]
# pre-processing 0.0009889602661132812
# Total number of circuits: 6
# sampler run time 0.04700136184692383
# post processing 0.003999948501586914
# val.shape (6, 2, 1, 2)
# swapp_list inital [0, 1, 2, 3]
# num_nested 0
# swapp_list [2, 0, 1, 3]
# after val.shape (1, 6, 2, 2)
# reshape_list [2, 3, 2, 2]

# %%
print(np.linalg.norm(res1["dvardp"] - res2["dvardp"]))
# Out:
# 7.619309948587718e-15

# %%
qnn_old.evaluate(("dfdop",), [x, x], [params, 2 * params, 3 * params], [params_op, params_op])
# Out:
# {Expec(I,dop,dfdop): array([[[[[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]],
#
#           [[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]]],
#
#
#          [[[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]],
#
#           [[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]]],
#
#
#          [[[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]],
#
#           [[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]]]],
#
#
#
#         [[[[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]],
#
#           [[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]]],
#
#
#          [[[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]],
#
#           [[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]]],
#
#
#          [[[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]],
#
#           [[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]]]]]),
#  'dfdop': array([[[[[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]],
#
#           [[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]]],
#
#
#          [[[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]],
#
#           [[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]]],
#
#
#          [[[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]],
#
#           [[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]]]],
#
#
#
#         [[[[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]],
#
#           [[ 1.        ,  0.48438978,  0.11832907,  0.34700452,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        ,  0.48438978,  0.11832907,  0.34700452]]],
#
#
#          [[[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]],
#
#           [[ 1.        , -0.23327826, -0.51670095, -0.27446989,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.23327826, -0.51670095, -0.27446989]]],
#
#
#          [[[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]],
#
#           [[ 1.        , -0.07905412,  0.01633802,  0.02904246,
#              1.        ,  1.        ,  1.        ,  1.        ],
#            [ 1.        ,  1.        ,  1.        ,  1.        ,
#              1.        , -0.07905412,  0.01633802,  0.02904246]]]]]),
#  'x': [0.5, 0.5],
#  'param': [array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#          0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#          0.79172504, 0.52889492]),
#   array([1.09762701, 1.43037873, 1.20552675, 1.08976637, 0.8473096 ,
#          1.29178823, 0.87517442, 1.783546  , 1.92732552, 0.76688304,
#          1.58345008, 1.05778984]),
#   array([1.64644051, 2.1455681 , 1.80829013, 1.63464955, 1.2709644 ,
#          1.93768234, 1.31276163, 2.675319  , 2.89098828, 1.15032456,
#          2.37517511, 1.58668476])],
#  'param_op': [array([0.56804456, 0.92559664, 0.07103606, 0.0871293 , 0.0202184 ,
#          0.83261985, 0.77815675, 0.87001215]),
#   array([0.56804456, 0.92559664, 0.07103606, 0.0871293 , 0.0202184 ,
#          0.83261985, 0.77815675, 0.87001215])]}

# %%
qnn.evaluate(("dfdop",), [x, x], [params, 2 * params, 3 * params], [params_op, params_op])
# Out:
# pre-processing 0.0020024776458740234
# Total number of circuits: 6
# sampler run time 0.037001609802246094
# post processing 0.004999399185180664
# val.shape (6, 2, 1, 8, 1)
# swapp_list inital [0, 1, 2, 3, 4]
# num_nested 0
# swapp_list [2, 0, 1, 3, 4]
# after val.shape (1, 6, 2, 8, 1)
# reshape_list [2, 3, 2, 8, 1]
# {Expec(I,dop,dfdop): array([[[[[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]],
#
#           [[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]]],
#
#
#          [[[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]],
#
#           [[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]]],
#
#
#          [[[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]],
#
#           [[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]]]],
#
#
#
#         [[[[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]],
#
#           [[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]]],
#
#
#          [[[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]],
#
#           [[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]]],
#
#
#          [[[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]],
#
#           [[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]]]]]),
#  'dfdop': array([[[[[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]],
#
#           [[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]]],
#
#
#          [[[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]],
#
#           [[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]]],
#
#
#          [[[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]],
#
#           [[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]]]],
#
#
#
#         [[[[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]],
#
#           [[ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452],
#            [ 1.        ],
#            [ 0.48438978],
#            [ 0.11832907],
#            [ 0.34700452]]],
#
#
#          [[[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]],
#
#           [[ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989],
#            [ 1.        ],
#            [-0.23327826],
#            [-0.51670095],
#            [-0.27446989]]],
#
#
#          [[[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]],
#
#           [[ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246],
#            [ 1.        ],
#            [-0.07905412],
#            [ 0.01633802],
#            [ 0.02904246]]]]]),
#  'x': [0.5, 0.5],
#  'param': [array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#          0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#          0.79172504, 0.52889492]),
#   array([1.09762701, 1.43037873, 1.20552675, 1.08976637, 0.8473096 ,
#          1.29178823, 0.87517442, 1.783546  , 1.92732552, 0.76688304,
#          1.58345008, 1.05778984]),
#   array([1.64644051, 2.1455681 , 1.80829013, 1.63464955, 1.2709644 ,
#          1.93768234, 1.31276163, 2.675319  , 2.89098828, 1.15032456,
#          2.37517511, 1.58668476])],
#  'param_op': [array([0.56804456, 0.92559664, 0.07103606, 0.0871293 , 0.0202184 ,
#          0.83261985, 0.77815675, 0.87001215]),
#   array([0.56804456, 0.92559664, 0.07103606, 0.0871293 , 0.0202184 ,
#          0.83261985, 0.77815675, 0.87001215])]}

# %%
ising_op = IsingHamiltonian(3, I="S", Z="S", ZZ="S")
qnn = QNN(fm, ising_op, Executor(), result_caching=False)
qnn_old = QNN_old(fm, ising_op, Executor(), result_caching=False)
x = 0.5
np.random.seed(0)
params = np.random.rand(qnn.num_parameters)
params_op = np.random.rand(qnn.num_parameters_operator)

# %%
qnn_old.evaluate(("dfdop",), x, params, params_op)
# Out:
# {Expec(I,dop,dfdop): array([1.        , 0.94972337, 0.57293204]),
#  'dfdop': array([1.        , 0.94972337, 0.57293204]),
#  'x': 0.5,
#  'param': array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#         0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#         0.79172504, 0.52889492]),
#  'param_op': array([0.56804456, 0.92559664, 0.07103606])}

# %%
qnn.evaluate(("f",), x, params, params_op)
# Out:
# pre-processing 0.0009999275207519531
# Total number of circuits: 1
# sampler run time 0.04000520706176758
# post processing 0.000993967056274414
# val.shape (1, 1, 1)
# swapp_list inital [0, 1, 2]
# num_nested 0
# swapp_list [2, 0, 1]
# after val.shape (1, 1, 1)
# reshape_list []
# {Expec(I,O,f): 1.4878041491339802,
#  'f': 1.4878041491339802,
#  'x': 0.5,
#  'param': array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#         0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#         0.79172504, 0.52889492]),
#  'param_op': array([0.56804456, 0.92559664, 0.07103606])}

# %%
qnn.evaluate(("f", "dfdop"), x, params, params_op)
# Out:
# pre-processing 0.0
# Total number of circuits: 1
# sampler run time 0.04099845886230469
# post processing 0.003003358840942383
# val.shape (1, 1, 2)
# swapp_list inital [0, 1, 2]
# num_nested 0
# swapp_list [2, 0, 1]
# after val.shape (2, 1, 1)
# reshape_list []
# reshape_list []
# C:\Users\DKR\Documents\Git Repositories\squlearn_fork\squlearn\src\squlearn\util\optree\optree_evaluate.py:53: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp = np.array(
# {Expec(I,O,f): 1.4878041491339802,
#  Expec(I,dop,dfdop): array([1.        , 0.94972337, 0.57293204]),
#  'f': 1.4878041491339802,
#  'dfdop': array([1.        , 0.94972337, 0.57293204]),
#  'x': 0.5,
#  'param': array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#         0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#         0.79172504, 0.52889492]),
#  'param_op': array([0.56804456, 0.92559664, 0.07103606])}

# %%
qnn.evaluate(("dfdop",), x, params, params_op)
# Out:
# pre-processing 0.0009996891021728516
# Total number of circuits: 1
# sampler run time 0.03999805450439453
# post processing 0.0010347366333007812
# val.shape (1, 1, 1, 3)
# swapp_list inital [0, 1, 2, 3]
# num_nested 0
# swapp_list [2, 0, 1, 3]
# after val.shape (1, 1, 1, 3)
# reshape_list [3]
# {Expec(I,dop,dfdop): array([1.        , 0.94972337, 0.57293204]),
#  'dfdop': array([1.        , 0.94972337, 0.57293204]),
#  'x': 0.5,
#  'param': array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#         0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#         0.79172504, 0.52889492]),
#  'param_op': array([0.56804456, 0.92559664, 0.07103606])}
